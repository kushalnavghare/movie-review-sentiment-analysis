# %%
# Load the Drive helper and mount
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %pwd
# Out:
# '/content'

# %%
# %cd drive/MyDrive/project_dsc540/data/
# Out:
# /content/drive/MyDrive/project_dsc540/data

# %%
import zipfile
from tqdm import tqdm
import os

# %%
def unzip_file(zip_file_path, extract_to):
  with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    total_files = len(zip_ref.infolist())
    with tqdm(total=total_files, desc='Extracting', unit='file') as pbar:
      for file_info in zip_ref.infolist():
        zip_ref.extract(file_info, extract_to)
        pbar.update(1)  # update progress bar

# %%
# %pwd
# Out:
# '/content/drive/MyDrive/project_dsc540/data'

# %%
# Example usage
zip_file_path = 'lastfm_train.zip'
extract_to = '/content/drive/MyDrive/project_dsc540/data/lastfm_train'

# %%
unzip_file(zip_file_path, extract_to)
# Out:
# Extracting: 100%|██████████| 857401/857401 [1:48:31<00:00, 131.68file/s]
