# %% [markdown]
# ## env setup

# %%
# Load the Drive helper and mount
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import json
import numpy as np

import matplotlib.pyplot as plt
import os
import seaborn as sns

# %%
import warnings
warnings.filterwarnings(action='ignore')

# %% [markdown]
# # data read

# %%
DATA_PATH = '/content/drive/MyDrive/project_dsc540/data'

# %%
def read_json_files(root_folder):
    data_list = []

    for foldername, subfolders, filenames in os.walk(root_folder):
        for filename in filenames:
            if filename.endswith('.json'):
                file_path = os.path.join(foldername, filename)
                with open(file_path, 'r') as file:
                    data = json.load(file)
                    data_list.append(data)

    return data_list

# %%
all_data = read_json_files(DATA_PATH)

# %%
len_lst = [len(x) for x in all_data]

# %%
all_data[5555]
# Out:
# {'artist': 'Virtue',
#  'timestamp': '2011-07-31 02:02:23.139351',
#  'similars': [['TRMTBUG128F428AC8F', 1],
#   ['TRJBPPV128F9345B97', 0.994824],
#   ['TRCSVVL128F92C40B9', 0.892419],
#   ['TRZIMSM128F42696E4', 0.810177],
#   ['TRVUTVO128F42663EE', 0.786492],
#   ['TROEAJV128F42AE9F0', 0.762198],
#   ['TRMDALK128F146AB1F', 0.748591],
#   ['TREFCKV128F4263F29', 0.741702],
#   ['TRPYOVU128F1495213', 0.715276],
#   ['TRSRFDH128F9324E45', 0.648969],
#   ['TRMWGOJ128F9324E33', 0.639792],
#   ['TRXUTGG128F931850B', 0.636084],
#   ['TRAQYZI12903CE97DC', 0.620509],
#   ['TRRMORR128F428EF30', 0.59899],
#   ['TRMNMQU128F42940F0', 0.585913],
#   ['TRKKWUZ128F92F5B44', 0.580999],
#   ['TRIXRJV128F92F5F85', 0.558555],
#   ['TRGSHCD128F4289B33', 0.527912],
#   ['TRHGQUQ128F4263D33', 0.503598],
#   ['TRGIBZJ128F4263D46', 0.493867],
#   ['TRRUGRC128F428B13D', 0.492986],
#   ['TRNWWGH128EF343579', 0.476737],
#   ['TRIECMB128F9318507', 0.473985],
#   ['TRHFESD128F92C90F6', 0.467695],
#   ['TRPBYHQ128F425EBC3', 0.457127],
#   ['TRRFAMK128F92C34E7', 0.456428],
#   ['TRDXAJN128EF34357D', 0.447122],
#   ['TRYYZXH128F42940E3', 0.443246],
#   ['TRHILAX128F930E9EB', 0.443022],
#   ['TRIAPEL128F4263D23', 0.443022],
#   ['TRCUNDZ128F92C34F2', 0.442391],
#   ['TRJADKL128F4263D54', 0.438929],
#   ['TRUAYNI128F427F0ED', 0.429114],
#   ['TRNJRLI128F428EEEA', 0.411316],
#   ['TRPMNJO128F92F5B5E', 0.386547],
#   ['TRGQWXV128F427F748', 0.368021],
#   ['TRHFLKG128F427F764', 0.368021],
#   ['TRGAMKL12903CA2693', 0.360646],
#   ['TRACHZH128F1453BE1', 0.360646],
#   ['TRYKUAK12903CA42C7', 0.354273],
#   ['TRCGNWM128F42890C1', 0.351759],
#   ['TRMVYXF128F14B0CDF', 0.349759],
#   ['TRAHWDN128F14ADE27', 0.349759],
#   ['TRBTAVY128F42AB292', 0.339554],
#   ['TRQKYVZ128F42936B8', 0.332308],
#   ['TRIQCJW128F9342128', 0.329559],
#   ['TREOTEZ128F42AF160', 0.312608],
#   ['TRQRYDP128F9341DD8', 0.285082],
#   ['TRYZFPF128F14A2288', 0.260081],
#   ['TRKNBHH128F92F57D1', 0.232268],
#   ['TRAAHRF128F92FE234', 0.224566],
#   ['TRCPXEV128F14ADE24', 0.223834],
#   ['TRYWLUC128F934A312', 0.223834],
#   ['TRVNYVP12903CA2698', 0.146388],
#   ['TRUHGEC128F4242FCC', 0.00708014],
#   ['TRIYOFK128F931882B', 0.00707982],
#   ['TRTUZGE128F14ADCCD', 0.00707982],
#   ['TRVKWOT128F9306756', 0.00707783],
#   ['TRNWQWL128F9309E50', 0.00707732],
#   ['TRINVYQ128F42514EF', 0.0070773],
#   ['TRIGOWA128F42514EA', 0.0070773]],
#  'tags': [['gospel', '100'],
#   ['female vocalists', '75'],
#   ['Neo-Soul', '75'],
#   ['soul', '50'],
#   ['rnb', '50'],
#   ['Virtue', '50'],
#   ['christian', '25'],
#   ['Contemporary Gospel', '25'],
#   ['Female Group', '25'],
#   ['Gospel Jams', '25'],
#   ['christian rnb', '25'],
#   ['CURTIS BROWN', '25'],
#   ['Contemporary Gospel Tag', '25']],
#  'track_id': 'TRMCNHP128F4263D58',
#  'title': "He's Been Good"}

# %%
pd.DataFrame(all_data)
# Out:
#                     artist                   timestamp  \
# 0                Nicolette  2011-07-30 16:58:50.555932
# 1                  Malavoi  2011-07-30 16:59:46.654453
# 2              The Maytals  2011-09-06 17:43:58.904851
# 3               Leo Marini  2011-07-30 17:08:43.085185
# 4      Rev. Timothy Wright  2011-07-30 16:58:43.881277
# ...                    ...                         ...
# 16153           Joe Bataan  2011-08-08 11:07:51.452151
# 16154           Themselves  2011-08-09 01:06:26.997504
# 16155        Daylight Torn  2011-08-10 04:18:27.573091
# 16156               Kalmah  2011-08-10 13:01:09.751283
# 16157     Robin Williamson  2011-08-10 00:11:27.417588
#
#                                                 similars  \
# 0      [[TRTPAKN128F4266109, 1], [TRSHHZA128F426610B,...
# 1                                                     []
# 2      [[TRPWVMH128F932E0F7, 0.9619], [TRLXSKC128F428...
# 3      [[TRUESIP128F4228788, 1], [TRQLIKG128F42256EB,...
# 4      [[TRAKIJI128F42494D1, 0.12755], [TRYDERE12903C...
# ...                                                  ...
# 16153  [[TRBBPGL128F933E34C, 1], [TRQLNEM128F933E349,...
# 16154  [[TRSUCWZ128F4296AF5, 1], [TRKHDKO128F4296B19,...
# 16155  [[TRBIDPO128F423508A, 1], [TRXHAJM128F4235082,...
# 16156  [[TRPZIMH128F42480D9, 1], [TRRYPQM128F42480DC,...
# 16157                                                 []
#
#                                                     tags            track_id  \
# 0      [[electropunk, 100], [glitch pop, 80], [dark e...  TRMMMPN128F426610E
# 1                                    [[Martinique, 100]]  TRMMMUZ128F4238E64
# 2      [[reggae, 100], [rocksteady, 75], [EARLY REGGA...  TRMMMBU128F9305AC3
# 3      [[boleros, 100], [bolero, 33], [recuerdos, 33]...  TRMMMLF128F4228771
# 4                                [[THE WRIGHT WAY, 100]]  TRMMMQV12903CA201E
# ...                                                  ...                 ...
# 16153  [[soul, 100], [funk, 100], [latin, 75], [groov...  TRMOJDH128F933E347
# 16154  [[experimental, 100], [electronic, 66], [antic...  TRMOJYF128F4296B04
# 16155                                                 []  TRMOJOJ128F4235084
# 16156  [[Melodic Death Metal, 100], [metal, 30], [fin...  TRMOJWO128F42480DA
# 16157                                    [[celtic, 100]]  TRMOJYK128F422A05A
#
#                                  title
# 0                              Nervous
# 1                              La filo
# 2                        Night And Day
# 3                         Acércate Más
# 4                       I Made It Over
# ...                                ...
# 16153                    Cycles of You
# 16154             Only Child Explosion
# 16155                     Lost in Time
# 16156              Wings of Blackening
# 16157  The Four Points Are Thus Beheld
#
# [16158 rows x 6 columns]
